# %%
import deepchem as dc
from deepchem.feat.graph_data import GraphData
from deepchem.feat import MolGraphConvFeaturizer
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./filtered_data_pIC50.csv')

# %%
df
# Out:
#      Molecule ChEMBL ID                                             Smiles  \
# 0          CHEMBL100034  CCCCNC(=O)N(CC(C)C)C[C@@H](O)[C@H](Cc1ccccc1)N...
# 1          CHEMBL100039  CC(C)CCN(C[C@@H](O)[C@H](Cc1ccccc1)NC(=O)[C@H]...
# 2          CHEMBL100040  CC(C)(C)NC(=O)[C@@H]1C[C@@H]2SCC[C@@H]2CN1C[C@...
# 3          CHEMBL100048  CC(C)(C)NC(=O)[C@@H]1C[C@@H]2SCC[C@@H]2CN1C[C@...
# 4          CHEMBL100089  CC(C)(C)NC(=O)[C@@H]1C[C@@H]2CCCC[C@@H]2CN1C[C...
# ...                 ...                                                ...
# 2047        CHEMBL99774  CC(C)(C)NC(=O)[C@@H]1C[C@@H]2CCCC[C@@H]2CN1C[C...
# 2048        CHEMBL99875  CC(C)(C)NC(=O)[C@@H]1C[C@@H]2SCC[C@@H]2CN1C[C@...
# 2049        CHEMBL99878  CC(C)(C)NC(=O)[C@@H]1C[C@@H]2SCC[C@@H]2CN1C[C@...
# 2050        CHEMBL99934  CCCNC(=O)N(CC(C)C)C[C@@H](O)[C@H](Cc1ccccc1)NC...
# 2051        CHEMBL99949  CC(C)(C)OC(=O)N[C@@H](Cc1ccccc1)[C@@H](O)C[C@@...
#
#      Molecule Name  Molecule Max Phase  Molecular Weight  #RO5 Violations  \
# 0              NaN                 NaN            604.75              1.0
# 1              NaN                 NaN            597.76              1.0
# 2              NaN                 NaN            730.85              1.0
# 3              NaN                 NaN            599.84              1.0
# 4              NaN                 NaN            740.99              1.0
# ...            ...                 ...               ...              ...
# 2047           NaN                 NaN            676.92              1.0
# 2048           NaN                 NaN            539.74              1.0
# 2049           NaN                 NaN            762.91              1.0
# 2050           NaN                 NaN            569.70              1.0
# 2051           NaN                 NaN            560.69              1.0
#
#       AlogP  Standard Value     pIC50  pChEMBL Value  ...     Target Type  \
# 0      2.76          126.00  6.899629           6.90  ...  SINGLE PROTEIN
# 1      3.10           13.00  7.886057           7.89  ...  SINGLE PROTEIN
# 2      2.85            0.20  9.698970            NaN  ...  SINGLE PROTEIN
# 3      2.53            1.70  8.769551           8.77  ...  SINGLE PROTEIN
# 4      3.42            0.50  9.301030           9.30  ...  SINGLE PROTEIN
# ...     ...             ...       ...            ...  ...             ...
# 2047   3.72           24.00  7.619789           7.62  ...  SINGLE PROTEIN
# 2048   4.00            6.60  8.180456           8.18  ...  SINGLE PROTEIN
# 2049   3.40           10.00  8.000000           8.00  ...  SINGLE PROTEIN
# 2050   2.32          518.00  6.285670           6.29  ...  SINGLE PROTEIN
# 2051   4.34           40.55  7.392009           7.39  ...  SINGLE PROTEIN
#
#       Document ChEMBL ID  Source ID     Source Description  \
# 0          CHEMBL1126824        1.0  Scientific Literature
# 1          CHEMBL1126824        1.0  Scientific Literature
# 2          CHEMBL1128092        1.0  Scientific Literature
# 3          CHEMBL1128633        1.0  Scientific Literature
# 4          CHEMBL1128092        1.0  Scientific Literature
# ...                  ...        ...                    ...
# 2047       CHEMBL1128092        1.0  Scientific Literature
# 2048       CHEMBL1128091        1.0  Scientific Literature
# 2049       CHEMBL1128092        1.0  Scientific Literature
# 2050       CHEMBL1126824        1.0  Scientific Literature
# 2051       CHEMBL1133609        1.0  Scientific Literature
#
#           Document Journal  Document Year Cell ChEMBL ID Properties  \
# 0               J Med Chem         1993.0            NaN        NaN
# 1               J Med Chem         1993.0            NaN        NaN
# 2     Bioorg Med Chem Lett         1995.0            NaN        NaN
# 3     Bioorg Med Chem Lett         1995.0            NaN        NaN
# 4     Bioorg Med Chem Lett         1995.0            NaN        NaN
# ...                    ...            ...            ...        ...
# 2047  Bioorg Med Chem Lett         1995.0            NaN        NaN
# 2048  Bioorg Med Chem Lett         1995.0            NaN        NaN
# 2049  Bioorg Med Chem Lett         1995.0            NaN        NaN
# 2050            J Med Chem         1993.0            NaN        NaN
# 2051            J Med Chem         2000.0            NaN        NaN
#
#      Action Type Standard Text Value
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
# ...          ...                 ...
# 2047         NaN                 NaN
# 2048         NaN                 NaN
# 2049         NaN                 NaN
# 2050         NaN                 NaN
# 2051         NaN                 NaN
#
# [2052 rows x 41 columns]

# %%
# 1. SMILES에서 그래프 형식으로 변환
featurizer = MolGraphConvFeaturizer()
features = featurizer.featurize(df["Smiles"])  # Smiles 컬럼에서 특징 추출

# %%
features
# Out:
# array([GraphData(node_features=[44, 30], edge_index=[2, 92], edge_features=None),
#        GraphData(node_features=[43, 30], edge_index=[2, 88], edge_features=None),
#        GraphData(node_features=[49, 30], edge_index=[2, 104], edge_features=None),
#        ...,
#        GraphData(node_features=[50, 30], edge_index=[2, 106], edge_features=None),
#        GraphData(node_features=[41, 30], edge_index=[2, 84], edge_features=None),
#        GraphData(node_features=[41, 30], edge_index=[2, 88], edge_features=None)],
#       dtype=object)

# %%
# 2. 레이블 설정 (pIC50)
labels = df["pIC50"].values

# %%
# 3. 가중치 (필요시 기본값으로 1 설정)
weights = None  # 기본적으로 None으로 설정. 커스텀 가중치가 있으면 지정.

# 4. 데이터셋 생성
dataset = dc.data.NumpyDataset(X=features, y=labels, w=weights)

# %%
# 데이터셋 확인
print(f"Number of samples in dataset: {len(dataset)}")
print(f"Feature shape: {dataset.X[0].node_features.shape[0]} nodes, {dataset.X[0].edge_index.shape[1]} edges")
print(f"First label: {dataset.y[0]}")
# Out:
# Number of samples in dataset: 2052
# Feature shape: 44 nodes, 92 edges
# First label: 6.899629455

# %%
# 데이터셋을 Train/Validation/Test로 나누기
splitter = dc.splits.RandomSplitter()
train_dataset, valid_dataset, test_dataset = splitter.train_valid_test_split(dataset)

# 확인
print(f"Train dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(valid_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
# Out:
# Train dataset size: 1641
# Validation dataset size: 205
# Test dataset size: 206

# %%
model = dc.models.GCNModel(n_tasks=1, mode='regression', dropout=0.2,batch_normalize=False)

# %%
model.fit(train_dataset, nb_epoch=100)
# Out:
# 0.6419707489013672

# %%
metric = dc.metrics.Metric(dc.metrics.pearson_r2_score)
print("Training set score:", model.evaluate(train_dataset, [metric]))
print("Test set score:", model.evaluate(test_dataset, [metric]))
# Out:
# Training set score: {'pearson_r2_score': 0.5662477620747329}
# Test set score: {'pearson_r2_score': 0.49987485298065687}
